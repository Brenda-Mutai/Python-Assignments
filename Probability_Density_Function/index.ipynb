# %% [markdown]
# # The Probability Density Function - Lab
#
# ## Introduction
# In this lab, we will look at building visualizations known as **density plots** to estimate the probability density for a given set of data.
#
# ## Objectives
#
# You will be able to:
#
# * Plot and interpret density plots and comment on the shape of the plot
# * Estimate probabilities for continuous variables by using interpolation
#
#
# ## Let's get started
#
# Let's import the necessary libraries for this lab.

# %%
# Import required libraries
import numpy as np
import matplotlib.pyplot as plt
# plt.style.use('ggplot')
import pandas as pd
import seaborn as sns

# %% [markdown]
# ## Import the data, and calculate the mean and the standard deviation
#
# - Import the dataset 'weight-height.csv' as a pandas dataframe.
#
# - Next, calculate the mean and standard deviation for weights and heights for men and women individually. You can simply use the pandas `.mean()` and `.std()` to do so.
#
# **Hint**: Use your pandas dataframe subsetting skills like `loc()`, `iloc()`, and `groupby()`

# %%
#import the dataset
data = pd.read_csv(r'weight-height.csv')
data.head()
# Out:
#   Gender     Height      Weight
# 0   Male  73.847017  241.893563
# 1   Male  68.781904  162.310473
# 2   Male  74.110105  212.740856
# 3   Male  71.730978  220.042470
# 4   Male  69.881796  206.349801

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Gender  10000 non-null  object
#  1   Height  10000 non-null  float64
#  2   Weight  10000 non-null  float64
# dtypes: float64(2), object(1)
# memory usage: 234.5+ KB

# %%
#import the dataset
data = pd.read_csv(r'weight-height.csv')
#dataframe for male and female
male_df = data.loc[data['Gender']=='Male']
female_df =  data.loc[data['Gender']=='Female']
#mean and standard deviation for male
male_height_mean = male_df['Height'].mean()
print(f"Male Height mean: {male_height_mean}")
male_height_sd = male_df['Height'].std()
print(f"Male Height sd: {male_height_sd}")
male_weight_mean = male_df['Weight'].mean()
print(f"Male Weight mean: {male_weight_mean}")
male_weight_sd = male_df['Weight'].std()
print(f"Male Weight sd: {male_weight_sd}")
#mean and standard deviation for female
female_height_mean=female_df['Height'].mean()
print(f"Female Height mean: {female_height_mean}")
female_height_sd=female_df['Height'].std()
print(f"Female Height sd: {female_height_sd}")
female_weight_mean=female_df['Weight'].mean()
print(f"Female Weight mean: {female_weight_mean}")
female_weight_sd=female_df['Weight'].std()
print(f"Female weight sd: {female_weight_sd}")

# Male Height mean: 69.02634590621737
# Male Height sd: 2.8633622286606517
# Male Weight mean: 187.0206206581929
# Male Weight sd: 19.781154516763813
# Female Height mean: 63.708773603424916
# Female Height sd: 2.696284015765056
# Female Weight mean: 135.8600930074687
# Female Weight sd: 19.022467805319007
# Out:
# Male Height mean: 69.02634590621741
# Male Height sd: 2.863362228660647
# Male Weight mean: 187.0206206581932
# Male Weight sd: 19.7811545167638
# Female Height mean: 63.70877360342507
# Female Height sd: 2.6962840157650536
# Female Weight mean: 135.86009300746835
# Female weight sd: 19.022467805319028

# %% [markdown]
# ## Plot histograms (with densities on the y-axis) for male and female heights
#
# - Make sure to create overlapping plots
# - Use binsize = 10, set alpha level so that overlap can be visualized

# %%
# plot histogram for male and female height
plt.figure(figsize=(10,6))
sns.histplot(male_df['Height'], bins=10, color='green', alpha=0.5, kde=True, label='Male Heights')
sns.histplot(female_df['Height'], bins=10, color='blue', alpha=0.5, kde=True, label='Female Heights')
plt.title('Height Distribution')
plt.ylabel('Density')
plt.xlabel('Height')
plt.legend()
plt.show()

# %%
# Record your observations - are these inline with your personal observations?
#Its shows that men tend to be taller than women on average.
# the average height of male and female is between 60-67
# Females have a height distribution around 60-65

# %%
#Record your observations - are these inline with your personal observations?

# Men tend to have higher values of heights in general than female
# The most common region for male and female heights is between 65 - 67 inches (about 5 and a half feet)
# Male heights have a slightly higher spread than female heights, hence the male height peak is slightly smaller than female height
# Both heights are normally distributed

# %% [markdown]
# ## Create a density function using interpolation
#
#
# - Write a density function density() that uses interpolation and takes in a random variable
# - Use `np.histogram()`
# - The function should return two lists carrying x and y coordinates for plotting the density function

# %%
def density(x):
    counts, bin_edges = np.histogram(x, bins=10, density=True)
    # bin_edges has length (bins+1), so take midpoints for plotting
    bin_centers = (bin_edges[:-1] + bin_edges[1:]) / 2
    return bin_centers, counts

# Generate test data and test the function
np.random.seed(5)
mu, sigma = 0, 0.1  # mean and standard deviation
s = np.random.normal(mu, sigma, 100)
x, y = density(s)
plt.plot(x, y, label='test')
plt.legend()
plt.show()

    

# Generate test data and test the function - uncomment to run the test
# np.random.seed(5)
# mu, sigma = 0, 0.1 # mean and standard deviation
# s = np.random.normal(mu, sigma, 100)
# x,y = density(s)
# plt.plot(x,y, label = 'test')
# plt.legend()

# %% [markdown]
# ## Add overlapping density plots to the histograms plotted earlier

# %%
# plotting histograms for female and male  heights with density
#plt.figure(figsize=(10,6))
#male height
sns.histplot(male_df['Height'], bins=10, color='green', alpha=0.5, kde=True, label='Male Heights')
#female height
sns.histplot(female_df['Height'], bins=10, color='blue', alpha=0.5, kde=True, label='Female Heights')
#density for male height
x,y=density(male_df.Height)
#density for female height
x,y=density(female_df.Height)
plt.title('Height Distribution')
plt.ylabel('Density')
plt.xlabel('Height')
plt.legend()
plt.show()

# %% [markdown]
# ## Repeat the above exercise for male and female weights

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Plot histogram for male and female weight
plt.figure(figsize=(10,6))

sns.histplot(male_df['Weight'], bins=10, color='green', alpha=0.5, kde=True, label='Male Weight')

sns.histplot(female_df['Weight'], bins=10, color='blue', alpha=0.5, kde=True, label='Female Weight')

plt.xlabel("Weight")
plt.ylabel("Density")
plt.title("Distribution of Male vs Female Weight")
plt.legend()
plt.show()

# %% [markdown]
# ## Write your observations in the cell below

# %%
# Record your observations - are these inline with your personal observations?
# Men are generally heavier than women
#Men weight is weight widespread than the female weight
#female weights are distributed until 200 unlike male weight distributed until  past 250

# What is the takeaway when comparing male and female heights and weights?
#Its easier to distinguish the weight of male and female than the height

# %%
# Record your observations - are these inline with your personal observations?

# The patterns and overlap are highly similar to what we see with height distributions
# Men generally are heavier than women
# The common region for common weights is around 160 lbs. 
# Male weight has slightly higher spread than female weight (i.e. more variation)
# Most females are around 130-140 lbs whereas most men are around 180 pounds.

#Takeaway

# Weight is more suitable to distinguish between males and females than height

# %% [markdown]
# ## Repeat the above experiments in seaborn and compare with your results

# %%
# Code for heights here
sns.histplot(male_df.Height,label='Male Height')
sns.histplot(female_df.Height,label='Female Height')
plt.ylabel('Density')
plt.xlabel('Height')
plt.legend()
plt.show()

# %%
# Code for weights here
sns.histplot(male_df.Weight,label='Male Weight')
sns.histplot(female_df.Weight,label='Female Weight')
plt.ylabel('Density')
plt.xlabel('Height')
plt.legend()
plt.show()

# %%
# Your comments on the two approaches here. 
# are they similar? what makes them different if they are?
# they are not similar because they have more bins

# %%
# Well, what do you think? Overlapping or side to side (or rather top/bottom)
#Overlapping is better for comparisons for the height and weight for male and female

# %% [markdown]
# ## Summary
#
# In this lesson, you learned how to build the probability density curves visually for a given dataset and compare the distributions visually by looking at the spread, center, and overlap. This is a useful EDA technique and can be used to answer some initial questions before embarking on a complex analytics journey.
